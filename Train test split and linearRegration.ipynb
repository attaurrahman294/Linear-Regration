# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import os
from string import ascii_letters
from sklearn.linear_model import LinearRegression
#model = LinearRegression()

# %%
data = pd.read_csv(r'E:\BI\atta\Python_visulization\practice\FuelConsumptionCo2\traintestt.csv')

# %%
data.head()
# Out:
#    Experience  Salary
# 0        14.0    6400
# 1        14.5    9000
# 2        15.0    6800
# 3        15.5    7000
# 4        16.0    7200

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()# creating a linear Regresst
model.fit (data[['Experience']],data['Salary'])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#To predict value for unknown x varaible
model.predict([[12]])
# Out:
# array([6053.17647059])

# %%
model.score(data[['Experience']],data['Salary'])
# Out:
# 0.9828848821233356

# %%
plt.figure(figsize=(16,9))
#plt.bar(data.Experience,model.predict(data[['Experience']]),alpha = 0.9,color='r')
plt.scatter(data.Experience,data.Salary,color = 'g',marker='*')
plt.plot(data.Experience,model.predict(data[['Experience']]))

# %%
sns.heatmap(data.head(10),vmin = 0, vmax = 21,annot=True)

# %%
sns.heatmap(data.corr(), annot = True,linewidths=1)
